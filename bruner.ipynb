# %%
from glob import glob

paths = glob('Data/Raw/'+'*.*')

# %%
paths
# Out:
# ['Data/Raw/wexpand-business_visitors_1775493721886.xls',
#  'Data/Raw/account_analytics_content_2026-01-07_2026-04-06.csv',
#  'Data/Raw/nurvai_visitors_1775493786729.xls',
#  'Data/Raw/account_overview_analytics.csv',
#  'Data/Raw/wexpand-business_content_1775493714982.xls',
#  'Data/Raw/wexpand-business_followers_1775493729426.xls',
#  'Data/Raw/wexpand-talent_followers_1775493759106.xls',
#  'Data/Raw/nurvai_followers_1775493792026.xls',
#  'Data/Raw/wexpand-talent_content_1775493744914.xls',
#  'Data/Raw/nurvai_content_1775493782101.xls']

# %%
from extract import linkedInExtraction,xExtraction
from transform import transform_metrics, transform_posts
from load import get_conn, pass_to_sql
from utils import find_files, send_mail, clear_temp_files

exceptions = []

BRANDS = [('nurvai','Nurvai'),('business','Wexpand'),('talent','Wexpand Talent')]

engine = get_conn()

try:

    posts_dfs = []
    metrics_dfs = []

    paths = find_files()

    if paths is None:
        raise FileNotFoundError
    
    for brand in BRANDS:
        m=''
        try:
            MetDF, PostDF = linkedInExtraction(paths,brand,engine)
            XMetDF, XPostDF = xExtraction(paths,brand,engine)

            metrics_dfs.append(MetDF)
            metrics_dfs.append(XMetDF)
            posts_dfs.append(PostDF)
            posts_dfs.append(XPostDF)            

            if MetDF is None and PostDF is not None:
                m = f"No Metrics Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
            
            elif MetDF is not None and PostDF is None:
                m = f"No Posts Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
            
            elif MetDF is None and PostDF is None:
                m = f"No Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
        except Exception as e:
            text = f'{str(e)} {m}'
            exceptions.append(text)
            print(text)
            continue
        
    


except Exception as e:
    text = f'{str(e)}: No files were porvided for the ETL'
    exceptions.append(text)
# Out:
# k
#  No Data found for Wexpand Talent's LinkedIN

# %%
from extract import linkedInExtraction,xExtraction
from transform import transform_metrics, transform_posts
from load import get_conn, pass_to_sql
from utils import find_files, send_mail, clear_temp_files

exceptions = []

big_m = ''

BRANDS = [('nurvai','Nurvai'),('business','Wexpand'),('talent','Wexpand Talent')]

engine = get_conn()

try:

    posts_dfs = []
    metrics_dfs = []

    paths = find_files()

    if paths is None:
        big_m = 'No files found for the ETL'
        raise FileNotFoundError
    
    for brand in BRANDS:
        m=''
        try:
            MetDF, PostDF = linkedInExtraction(paths,brand,engine)
            XMetDF, XPostDF = xExtraction(paths,brand,engine)

            metrics_dfs.append(MetDF)
            metrics_dfs.append(XMetDF)
            posts_dfs.append(PostDF)
            posts_dfs.append(XPostDF)            

            if MetDF is None and PostDF is not None:
                m = f"No Metrics Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
            
            elif MetDF is not None and PostDF is None:
                m = f"No Posts Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
            
            elif MetDF is None and PostDF is None:
                m = f"No Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
        except Exception as e:
            text = f'{type(e).__name__}: {str(e)} {m}'
            exceptions.append(text)
            continue

    no_mets = True
    no_posts = True
    small_m = ''

    try: 
        if all(df is None for df in metrics_dfs) or metrics_dfs == []:
            small_m = 'No Files For Metrics Found' 
            raise FileNotFoundError
        
        else: 
            no_mets = False
    
    except Exception as e:
        text = f'{type(e).__name__}: {str(e)} {small_m}'
        exceptions.append(text)
    
    try:
        if all(df is None for df in posts_dfs) or posts_dfs == []:
            small_m = 'No Files For Posts Found'
            raise FileNotFoundError

        else:
            no_posts = False

    except Exception as e:
        text = f'{type(e).__name__}: {str(e)} {small_m}'

    if no_mets and no_posts:
        big_m = 'Files Were Provided But Were Incomplete or Mistaken'
        raise FileNotFoundError
    
    if not(no_mets):
        dfs = []
        for df in metrics_dfs:
            if df is not None:
                dfs.append(df)
        
        MetricsDF = transform_metrics(dfs,engine)

except Exception as e:
    text = f'{type(e).__name__}: {str(e)} {big_m}'
    exceptions.append(text)


print(exceptions)
# Out:
# ["FileNotFoundError:  No Data found for Wexpand Talent's LinkedIN"]

# %%
MetricsDF
# Out:
#      account_id  bookmarks  clicks  comments       date  engagementRate  \
# 0             2       <NA>       0         0 2026-01-01        0.000000
# 1             2       <NA>       0         0 2026-01-02        0.000000
# 2             2       <NA>       0         0 2026-01-03        0.000000
# 3             2       <NA>       0         0 2026-01-04        0.000000
# 4             2       <NA>       0         0 2026-01-05        0.000000
# ..          ...        ...     ...       ...        ...             ...
# 360           3       <NA>       0         0 2025-12-27        0.000000
# 361           3       <NA>       0         0 2025-12-28        0.000000
# 362           3       <NA>       4         0 2025-12-29        0.285714
# 363           3       <NA>       6         0 2025-12-30        0.400000
# 364           3       <NA>       0         0 2025-12-31        0.000000
#
#      engagements  followersGained  followersTotal  impressions  reactions  \
# 0              0                0            <NA>            0          0
# 1              0                0            <NA>            4          0
# 2              0                0            <NA>            0          0
# 3              0                0            <NA>            0          0
# 4              0                0            <NA>            0          0
# ..           ...              ...             ...          ...        ...
# 360            0                0            <NA>            8          0
# 361            0                0            <NA>           24          0
# 362            4                0            <NA>           14          0
# 363            6                0            <NA>           15          0
# 364            0                2            <NA>           17          0
#
#      shares  unfollows                          row_hash  \
# 0         0       <NA>  7dd44d76bed60acec6c3e3b8be6d56cd
# 1         0       <NA>  3aa9c28779c786db80b50c52465dc61a
# 2         0       <NA>  e2ba4f4aac605e8f84f89e85eea1d778
# 3         0       <NA>  2c09d084ee6a6132f76e75bf1a3a5a1d
# 4         0       <NA>  b7aa690047d7340e3b22ad350542708c
# ..      ...        ...                               ...
# 360       0       <NA>  83f2e59d996f745a2941db410af871ce
# 361       0       <NA>  93802e308cc1805b4e95046056d299e0
# 362       0       <NA>  25eabfea7e80b0c165ed5b1432c2aaf0
# 363       0       <NA>  f550b68cc3b827538ddcac1ce32f2ef4
# 364       0       <NA>  6bbea15fce8570b66c63a89a8c7d104f
#
#                     updated_at
# 0   2026-05-28 09:56:56.254023
# 1   2026-05-28 09:56:56.254023
# 2   2026-05-28 09:56:56.254023
# 3   2026-05-28 09:56:56.254023
# 4   2026-05-28 09:56:56.254023
# ..                         ...
# 360 2026-05-28 09:56:56.254023
# 361 2026-05-28 09:56:56.254023
# 362 2026-05-28 09:56:56.254023
# 363 2026-05-28 09:56:56.254023
# 364 2026-05-28 09:56:56.254023
#
# [790 rows x 15 columns]

# %%
for path in paths:
    if 'content' in path:
        print('daa')
# Out:
# daa
# daa
# daa

# %%
import pandas as pd
pd.concat(dfs).columns
# Out:
# Index(['generalPageViews', 'generalPageUniqueVisitors', 'lifePageViews',
#        'lifePageUniqueVisitors', 'jobsPageViews', 'jobsPageUniqueVisitors',
#        'pageViewsDesktop', 'pageViewsMobile', 'pageViews',
#        'uniqueVisitorsDesktop', 'uniqueVisitorsMobile', 'uniqueVisitors',
#        'followersGained', 'impressions', 'clicks', 'reactions', 'comments',
#        'shares', 'engagementRate', 'date', 'account_id', 'engagements',
#        'followersTotal'],
#       dtype='object')

# %%
for df in dfs:
    print(df.columns)
# Out:
# Index(['generalPageViews', 'generalPageUniqueVisitors', 'lifePageViews',
#        'lifePageUniqueVisitors', 'jobsPageViews', 'jobsPageUniqueVisitors',
#        'pageViewsDesktop', 'pageViewsMobile', 'pageViews',
#        'uniqueVisitorsDesktop', 'uniqueVisitorsMobile', 'uniqueVisitors',
#        'followersGained', 'impressions', 'clicks', 'reactions', 'comments',
#        'shares', 'engagementRate', 'date', 'account_id', 'engagements',
#        'followersTotal'],
#       dtype='object')
# Index(['generalPageViews', 'generalPageUniqueVisitors', 'lifePageViews',
#        'lifePageUniqueVisitors', 'jobsPageViews', 'jobsPageUniqueVisitors',
#        'pageViewsDesktop', 'pageViewsMobile', 'pageViews',
#        'uniqueVisitorsDesktop', 'uniqueVisitorsMobile', 'uniqueVisitors',
#        'impressions', 'clicks', 'reactions', 'comments', 'shares',
#        'engagementRate', 'followersGained', 'date', 'account_id',
#        'engagements', 'followersTotal'],
#       dtype='object')

# %%
from extract import linkedInExtraction,xExtraction
from transform import transform_metrics, transform_posts
from load import get_conn, pass_to_sql
from utils import find_files, send_mail, clear_temp_files

exceptions = []

big_m = ''

BRANDS = [('nurvai','Nurvai'),('business','Wexpand'),('talent','Wexpand Talent')]

engine = get_conn()
delete_files = True
message = 'Load succesful'

try:

    posts_dfs = []
    metrics_dfs = []

    paths = find_files()

    if paths is None:
        big_m = 'No files found for the ETL'
        raise FileNotFoundError
    
    for brand in BRANDS:
        m=''
        try:
            MetDF, PostDF = linkedInExtraction(paths,brand,engine)
            XMetDF, XPostDF = xExtraction(paths,brand,engine)

            metrics_dfs.append(MetDF)
            metrics_dfs.append(XMetDF)
            posts_dfs.append(PostDF)
            posts_dfs.append(XPostDF)            

            if MetDF is None and PostDF is not None:
                m = f"No Metrics Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
            
            elif MetDF is not None and PostDF is None:
                m = f"No Posts Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
            
            elif MetDF is None and PostDF is None:
                m = f"No Data found for {brand[1]}'s LinkedIN"
                raise FileNotFoundError
        except Exception as e:
            text = f'{type(e).__name__}: {str(e)} {m}'
            exceptions.append(text)
            continue

    no_mets = True
    no_posts = True
    small_m = ''

    try: 
        if all(df is None for df in metrics_dfs) or metrics_dfs == []:
            small_m = 'No Files For Metrics Found' 
            raise FileNotFoundError
        
        else: 
            no_mets = False
    
    except Exception as e:
        text = f'{type(e).__name__}: {str(e)} {small_m}'
        exceptions.append(text)
    
    try:
        if all(df is None for df in posts_dfs) or posts_dfs == []:
            small_m = 'No Files For Posts Found'
            raise FileNotFoundError

        else:
            no_posts = False

    except Exception as e:
        text = f'{type(e).__name__}: {str(e)} {small_m}'

    if no_mets and no_posts:
        big_m = 'Files Were Provided But Were Incomplete or Mistaken'
        raise FileNotFoundError
    
    if not(no_mets):
        dfs = []
        for df in metrics_dfs:
            if df is not None:
                dfs.append(df)
        
        MetricsDF = transform_metrics(dfs,engine)

        try:
            pass_to_sql(MetricsDF,'Metrics',engine)
        except Exception as e:
            delete_files = False
            text = f'{type(e).__name__}: {str(e)}'
            exceptions.append(text)
        

    if not(no_posts):
        dfs = []
        for df in posts_dfs:
            if df is not None:
                dfs.append(df)
        
        PostsDF, TermsDF, exceps = transform_posts(dfs,engine)

        if exceps != []:
            for excep in exceps:
                exceptions.append(excep)

        try:
            pass_to_sql(PostsDF,'Posts',engine)
        except Exception as e:
            delete_files = False
            text = f'{type(e).__name__}: {e}'
            exceptions.append(text)
        
        try:
            pass_to_sql(TermsDF,'Terms',engine)
        except Exception as e:
            delete_files = False
            text = f'{type(e).__name__}: {e}'
            exceptions.append(text)

except Exception as e:
    text = f'{type(e).__name__}: {str(e)} {big_m}'
    exceptions.append(text)

if delete_files and paths is not None:
    clear_temp_files(paths)


if exceptions != []:
    message = 'Exceptions where encountered while loading. The exceptions ecountered were the following: \n'
    exceptions = '\n'.join(exceptions)
    message += exceptions

send_mail('File Load Completion Status',message)
